# %%
#Mount Drive
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Import Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
#See the data
dataframe = pd.read_csv('/content/drive/MyDrive/Tugas_JST_2/LSTM/Univariate/train_csv.csv', usecols=[2], engine='python')
dataset = dataframe.values
dataframe
# Out:
#     feature
# 0    237.97
# 1     57.93
# 2     90.53
# 3    260.75
# 4     49.70
# ..      ...
# 75   469.72
# 76   406.79
# 77   128.91
# 78    85.28
# 79   121.12
#
# [80 rows x 1 columns]

# %%
# MinMax scaling for 0 to 1
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
len(dataset)
# Out:
# 80

# %%
# splitting the 80% training and 20% testing
train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 64 16

# %%
# function for pre processing data for RNN.
def create_dataset(dataset, no_seq=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-no_seq-1):
        a = dataset[i:(i+no_seq), 0]
        dataX.append(a)
        dataY.append(dataset[i + no_seq, 0])
    return np.array(dataX), np.array(dataY)

# %%
# with number of sequence=1, splitting of data takes place. 
no_seq = 1
trainX, trainY = create_dataset(train, no_seq)
testX, testY = create_dataset(test, no_seq)
print(len(trainX),len(trainY))
print(len(testX),len(testY))
# Out:
# 62 62
# 14 14

# %%
#Reshape dataset
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
#Make Model

model = Sequential()

model.add(LSTM(units=50, return_sequences=True,input_shape=(1, no_seq)))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dense(units=25))
model.add(Dense(units=1))

model_url = '/content/drive/MyDrive/Tugas_JST_2/LSTM/Univariate/univariate.h5'
model.save(model_url)
print("Saved")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved

# %%
#compile
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
#Evaluation, replace with 1, if you want to display the epoch
model.fit(trainX, trainY, epochs=50, batch_size=32, verbose=1)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 20s 9ms/step - loss: 0.0942
# Epoch 2/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0868
# Epoch 3/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0730
# Epoch 4/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0651
# Epoch 5/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0591
# Epoch 6/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0583
# Epoch 7/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0508
# Epoch 8/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0488
# Epoch 9/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0394
# Epoch 10/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0421
# Epoch 11/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0379
# Epoch 12/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0378
# Epoch 13/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0377
# Epoch 14/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0338
# Epoch 15/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0362
# Epoch 16/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0362
# Epoch 17/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0360
# Epoch 18/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0390
# Epoch 19/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0363
# Epoch 20/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0355
# Epoch 21/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0371
# Epoch 22/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0380
# Epoch 23/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0367
# Epoch 24/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0326
# Epoch 25/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0329
# Epoch 26/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0340
# Epoch 27/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0365
# Epoch 28/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0349
# Epoch 29/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0379
# Epoch 30/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0355
# Epoch 31/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0332
# Epoch 32/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0357
# Epoch 33/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0351
# Epoch 34/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0368
# Epoch 35/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0360
# Epoch 36/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0343
# Epoch 37/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0351
# Epoch 38/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0365
# Epoch 39/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0362
# Epoch 40/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0374
# Epoch 41/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0339
# Epoch 42/50
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0304
# Epoch 43/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0353
# Epoch 44/50
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0349
# Epoch 45/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0364
# Epoch 46/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0353
# Epoch 47/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0342
# Epoch 48/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0337
# Epoch 49/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0379
# Epoch 50/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0345

# %%
#show the graph of loss function
plt.title('Loss')
plt.plot(model.history.history['loss'], label='loss value')
plt.legend()
plt.show()

# %%
#Prediction use RSME
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))

trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[no_seq:len(trainPredict)+no_seq, :] = trainPredict
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(no_seq*2)+1:len(dataset)-1, :] = testPredict
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Train Score: 83.68 RMSE
# Test Score: 124.42 RMSE

# %%
#Predict Future
inference_data = pd.read_csv('/content/drive/MyDrive/Tugas_JST_2/LSTM/Univariate/test_csv.csv')

No_test_data = len(inference_data)

# Number of features to be found.
print(No_test_data)
# Out:
# 40

# %%
# Prediction taking the last dataset of train and predicting the rest 39 features.

for i in range(79, 79+No_test_data):
    
    # last day of the training dataset.
    if i == 79:
        last_day = dataframe[i:i+1].values
        last_day = scaler.transform(last_day)
        X_test = []
        X_test.append(last_day)
        X_test = np.array(X_test)
        X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
        pred_price = model.predict(X_test)
        pred_price = scaler.inverse_transform(pred_price)
        print(pred_price)
        
    # rest 39 features.   
    else:
        last_day = pred_value
        last_day = scaler.transform(last_day)
        X_test = []
        X_test.append(last_day)
        X_test = np.array(X_test)
        X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
        pred_price = model.predict(X_test)
        pred_price = scaler.inverse_transform(pred_price)
        print(pred_price)
        
    # replacing the old prediction value with new for next feature prediction.
    pred_value = pred_price
# Out:
# [[130.00917]]
# [[131.8227]]
# [[132.19307]]
# [[132.2687]]
# [[132.28418]]
# [[132.28734]]
# [[132.288]]
# [[132.2881]]
# [[132.28812]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
# [[132.28815]]
